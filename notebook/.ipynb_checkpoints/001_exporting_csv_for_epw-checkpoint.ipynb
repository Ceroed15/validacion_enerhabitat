# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from dateutil.parser import parse

# %%
archivo = "../epw/enerhabitat-2025-10-20.csv"
epw = pd.read_csv(archivo,
                 index_col=0,
                 parse_dates=True,
                 usecols = ['Time', 'Tsa_1'])
epw
# Out:
#                            Tsa_1
# Time
# 2025-05-15 00:00:00-06:00   25.5
# 2025-05-15 00:01:00-06:00   25.4
# 2025-05-15 00:02:00-06:00   25.4
# 2025-05-15 00:03:00-06:00   25.4
# 2025-05-15 00:04:00-06:00   25.4
# ...                          ...
# 2025-05-15 23:55:00-06:00   25.6
# 2025-05-15 23:56:00-06:00   25.5
# 2025-05-15 23:57:00-06:00   25.5
# 2025-05-15 23:58:00-06:00   25.5
# 2025-05-15 23:59:00-06:00   25.5
#
# [1440 rows x 1 columns]

# %%
epw['P'] = 100_000
epw['Ig'] = 0
epw['Ib'] = 0
epw['HR'] = 23
epw['Ig'] = 0
epw['WS'] = 0
epw['WD'] = 0

epw.rename(columns = {'Tsa_1' : 'Tsa'}, inplace = True)

# %%
epw
# Out:
#                             Tsa       P  Ig  Ib  Hr
# Time
# 2025-05-15 00:00:00-06:00  25.5  100000   0   0  23
# 2025-05-15 00:01:00-06:00  25.4  100000   0   0  23
# 2025-05-15 00:02:00-06:00  25.4  100000   0   0  23
# 2025-05-15 00:03:00-06:00  25.4  100000   0   0  23
# 2025-05-15 00:04:00-06:00  25.4  100000   0   0  23
# ...                         ...     ...  ..  ..  ..
# 2025-05-15 23:55:00-06:00  25.6  100000   0   0  23
# 2025-05-15 23:56:00-06:00  25.5  100000   0   0  23
# 2025-05-15 23:57:00-06:00  25.5  100000   0   0  23
# 2025-05-15 23:58:00-06:00  25.5  100000   0   0  23
# 2025-05-15 23:59:00-06:00  25.5  100000   0   0  23
#
# [1440 rows x 5 columns]

# %%
epw.plot(subplots=True,figsize=(20,40));

# %%
def df2epw(df):
    df['anio']    = df.index.year
    df['mes']     = df.index.month
    df['dia']     = df.index.day
    df['hora']    = df.index.hour
    df['minutos'] = df.index.minute
    return df[1:]

# %%
columnas = ['anio','mes','dia','hora','minutos',
            'To','RH','P',"Ig","Ib",'WD','WS']
tmp = df2epw(epw)

tmp.to_csv( "../epw/enerhabitat-2025-10-20.csv",
           columns=columnas,header=False,index=False)
tmp.to_csv( "../epw/Temixco_2018.csv",
           columns=columnas,header=False,index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 5
#       1 columnas = ['anio','mes','dia','hora','minutos',
#       2             'To','RH','P',"Ig","Ib",'WD','WS']
#       3 tmp = df2epw(epw)
# ----> 5 tmp.to_csv( "../epw/enerhabitat-2025-10-20.csv",
#       6            columns=columnas,header=False,index=False)
#       7 tmp.to_csv( "../epw/Temixco_2018.csv",
#       8            columns=columnas,header=False,index=False)
#
# File ~\OneDrive\Escritorio\LIER\Pyhon0_Usuario\WPy64-31241\python-3.12.4.amd64\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
# ...

# %%
tmp
